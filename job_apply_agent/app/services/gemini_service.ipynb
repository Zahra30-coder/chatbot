# %%
import os
from pathlib import Path
#import google.generativeai as genai
from dotenv import load_dotenv
from app.services.gemini_service import model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 from pathlib import Path
#       3 #import google.generativeai as genai
# ----> 4 from dotenv import load_dotenv
#       5 from app.services.gemini_service import model
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
load_dotenv(r"D:\CHATBOT\.env")
print(os.getenv("GEMINI_API_KEY"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 load_dotenv(r"D:\CHATBOT\.env")
#       2 print(os.getenv("GEMINI_API_KEY"))
#
# NameError: name 'load_dotenv' is not defined

# %%
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))
# Out:
# api_key=os.getenv : The term 'api_key=os.getenv' is not recognized as the name of a cmdlet, function, script file, or
# operable program. Check the spelling of the name, or if a path was included, verify that the path is correct and try
# again.
# At line:2 char:17
# + genai.configure(api_key=os.getenv("GEMINI_API_KEY"))
# +                 ~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : ObjectNotFound: (api_key=os.getenv:String) [], CommandNotFoundException
#     + FullyQualifiedErrorId : CommandNotFoundException

# %%
model = genai.GenerativeModel("gemini-2.5-flash")
print(model)
# Out:
# model : The term 'model' is not recognized as the name of a cmdlet, function, script file, or operable program. Check
# the spelling of the name, or if a path was included, verify that the path is correct and try again.
# At line:2 char:1
# + model = genai.GenerativeModel("gemini-2.5-flash")
# + ~~~~~
#     + CategoryInfo          : ObjectNotFound: (model:String) [], CommandNotFoundException
#     + FullyQualifiedErrorId : CommandNotFoundException
#
# model : The term 'model' is not recognized as the name of a cmdlet, function, script file, or operable program. Check
# the spelling of the name, or if a path was included, verify that the path is correct and try again.
# At line:3 char:7
# + print(model)
# +       ~~~~~
#     + CategoryInfo          : ObjectNotFound: (model:String) [], CommandNotFoundException
#     + FullyQualifiedErrorId : CommandNotFoundException
